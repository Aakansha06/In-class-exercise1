# %% [markdown]
# <a href="https://colab.research.google.com/github/unt-iialab/INFO5731_Spring2020/blob/master/In_class_exercise/In_class_exercise_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The fourth in-class-exercise (20 points in total)**

# %% [markdown]
# # 1. Text Data Preprocessing
#
# Here is a [legal case](https://github.com/unt-iialab/INFO5731_FALL2020/blob/master/In_class_exercise/01-05-1%20%20Adams%20v%20Tanner.txt) we collected from westlaw, please follow the steps we mentioned in lesson 5 to clean the data:
#
#
#
# ## 1.1 Basic feature extraction using text data (4 points)
#
# *   Number of sentences
# *   Number of words
# *   Number of characters
# *   Average word length
# *   Number of stopwords
# *   Number of special characters
# *   Number of numerics
# *   Number of uppercase words
#
# ## 1.2 Basic Text Pre-processing of text data (4 points)
#
# *   Lower casing
# *   Punctuation removal
# *   Stopwords removal
# *   Frequent words removal
# *   Rare words removal
# *   Spelling correction
# *   Tokenization
# *   Stemming
# *   Lemmatization
#
# ## 1.3 Save all the **clean sentences** to a **csv file** (one column, each raw is a sentence) after finishing all the steps above. (4 points)
#
#
# ## 1.4 Advance Text Processing (Extra credit: 4 points)
#
# *   Calculate the term frequency of all the terms.
# *   Print out top 10 1-gram, top 10 2-grams, and top 10 3-grams terms as features.

# %% [markdown]
# # 2. Python Regular Expression

# %% [markdown]
# ## 2.1 Write a Python program to remove leading zeros from an IP address. (4 points)
#
# ip = "260.08.094.109"

# %%
# Write your code here

def address(ip):
  ipa = ".".join([str(int(a)) for a in ip.split(".")])
  return ipa;
ip = "260.08.094.109"
print(address(ip))
# Out:
# 260.8.94.109

# %%
file = open("/content/sample_data/exercise4.txt","r")
print(file.read())
# Out:
# 5 Ala. 740
# Supreme Court of Alabama.
# ADAMS
# v.
# TANNER AND HORTON.
# June Term, 1843.
# Synopsis
# WRIT of Error to the Circuit Court of Sumter.
#
#
#
# West Headnotes (2)
#
#
# [1]
# Chattel Mortgages
# Crops
# A growing crop has such an existence as to be the subject-matter of a mortgage or other contract which passes an interest to vest in possession, either immediately or at a future time.
# 4 Cases that cite this headnote
#
# [2]
# Creditors’ Remedies
# Lien and Priority
# Under St.1821, prohibiting a levy on a crop until it has been gathered, no lien attaches in favor of a fi. fa. on a growing crop, nor does such lien attach until after the crop has been gathered.
# 5 Cases that cite this headnote
#
# ...

# %%
import requests
url = 'https://raw.githubusercontent.com/unt-iialab/INFO5731_FALL2020/master/In_class_exercise/01-05-1%20%20Adams%20v%20Tanner.txt'
githuburl = requests.get(url)
data = githuburl.text
print(data)
# Out:
# 5 Ala. 740
# Supreme Court of Alabama.
# ADAMS
# v.
# TANNER AND HORTON.
# June Term, 1843.
# Synopsis
# WRIT of Error to the Circuit Court of Sumter.
#
#
#
# West Headnotes (2)
#
#
# [1]
# Chattel Mortgages
# Crops
# A growing crop has such an existence as to be the subject-matter of a mortgage or other contract which passes an interest to vest in possession, either immediately or at a future time.
# 4 Cases that cite this headnote
#
# [2]
# Creditors’ Remedies
# Lien and Priority
# Under St.1821, prohibiting a levy on a crop until it has been gathered, no lien attaches in favor of a fi. fa. on a growing crop, nor does such lien attach until after the crop has been gathered.
# 5 Cases that cite this headnote
#
# ...

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
print(len(sent_tokenize(data)))
# Out:
# 173

# %%
print(len(word_tokenize(data)))
# Out:
# 4368

# %%
print(len(data))
# Out:
# 20613

# %%
x = word_tokenize(data)
y = []
for i in x:
  y.append(len(x))
print("average of the words:",sum(y)/len(x))
# Out:
# average of the words: 4368.0

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stopword = stopwords.words('english')
stop=[]
for l in d:
  if l in stopword:
    stop.append(l)
print(len(stop))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 4

# %%
file = len(data)-len(re.findall('[\w]',data))
print(file)
# Out:
# 4710

# %%
text=[]
for x in data:
  if x.isdigit():
    text.append(x)
print(len(text))
# Out:
# 356

# %%
uppercase = []
for l in d:
  if l.isupper():
    uppercase.append(l)
print(len(uppercase))
# Out:
# 2

# %%
file = data.lower()
file1= re.sub(r'[^\w\s]','',file)

# %%
file2=''
split = file1.split()
for x in split:
  for y in x.split():
    if not y in stop:
      file2 = file2 + '' + y 
    file2 = file2 + '\n'
print(file2)
# Out:
# 5
# ala
# 740
# supreme
# court
# of
# alabama
# adams
# v
# tanner
# and
# horton
# june
# term
# 1843
# synopsis
# writ
# of
# error
# to
# the
# circuit
# court
# of
# sumter
# west
# headnotes
# 2
# 1
# chattel
# mortgages
# crops
# a
# growing
# crop
# has
# such
# an
# existence
# as
# to
# be
# the
# subjectmatter
# of
# a
# mortgage
# or
# other
# contract
# which
# passes
# an
# interest
# to
# vest
# in
# possession
# either
# immediately
# or
# at
# a
# future
# time
# 4
# cases
# that
# cite
# this
# headnote
# 2
# creditors
# remedies
# lien
# and
# priority
# under
# st1821
# prohibiting
# a
# levy
# on
# a
# crop
# until
# it
# has
# been
# gathered
# no
# lien
# attaches
# in
# favor
# of
# a
# fi
# fa
# on
# a
# growing
# crop
# nor
# does
# such
# lien
# attach
# until
# after
# the
# crop
# has
# been
# gathered
# 5
# cases
# that
# cite
# this
# headnote
# 1
# this
# was
# a
# trial
# of
# the
# right
# of
# property
# under
# the
# statute
# in
# november
# 1840
# ...

# %%
import pandas as pd
text = pd.Series(file2.split()).value_counts()[:10]
text
# Out:
# the     337
# of      142
# to      116
# a        84
# and      83
# in       81
# it       80
# that     56
# was      54
# is       50
# dtype: int64

# %%
file3 = '' 
s = list(text.index)
for a in file2.split('\n'):
  for b in a.split():
    if not b in text:
      file3 = file3 + '' + b 
    file3 = file3 + '\n'
print(file3)
# Out:
# 5
# ala
# 740
# supreme
# court
#
# alabama
# adams
# v
# tanner
#
# horton
# june
# term
# 1843
# synopsis
# writ
#
# error
#
#
# circuit
# court
#
# sumter
# west
# headnotes
# 2
# 1
# chattel
# mortgages
# crops
#
# growing
# crop
# has
# such
# an
# existence
# as
#
# be
#
# subjectmatter
#
#
# mortgage
# or
# other
# contract
# which
# passes
# an
# interest
#
# vest
#
# possession
# either
# immediately
# or
# at
#
# future
# time
# 4
# cases
#
# cite
# this
# headnote
# 2
# creditors
# remedies
# lien
#
# priority
# under
# st1821
# prohibiting
#
# levy
# on
#
# crop
# until
#
# has
# been
# gathered
# no
# lien
# attaches
#
# favor
#
#
# fi
# fa
# on
#
# growing
# crop
# nor
# does
# such
# lien
# attach
# until
# after
#
# crop
# has
# been
# gathered
# 5
# cases
#
# cite
# this
# headnote
# 1
# this
#
#
# trial
#
#
# right
#
# property
# under
#
# statute
#
# november
# 1840
# an
# execution
# issued
# from
#
# circuit
# court
#
# sumter
# at
#
# suit
#
#
# plaintiff
#
# ...

# %%
read = pd.Series(file2.split()).value_counts()[-20:]
read
# Out:
# grain          1
# easy           1
# according      1
# 1936           1
# 103            1
# absent         1
# rees           1
# pay            1
# delivered      1
# weakley        1
# paramount      1
# voluntarily    1
# remarking      1
# plantation     1
# decided        1
# 745            1
# h              1
# wend           1
# inquire        1
# harrisons      1
# dtype: int64

# %%
file4 = ''
for a in file3.split('\n'):
  for b in a.split():
    if not b in text:
      file4 = file4 + '' + b 
    file4 = file4 + '\n'
print(file4)
# Out:
# 5
# ala
# 740
# supreme
# court
# alabama
# adams
# v
# tanner
# horton
# june
# term
# 1843
# synopsis
# writ
# error
# circuit
# court
# sumter
# west
# headnotes
# 2
# 1
# chattel
# mortgages
# crops
# growing
# crop
# has
# such
# an
# existence
# as
# be
# subjectmatter
# mortgage
# or
# other
# contract
# which
# passes
# an
# interest
# vest
# possession
# either
# immediately
# or
# at
# future
# time
# 4
# cases
# cite
# this
# headnote
# 2
# creditors
# remedies
# lien
# priority
# under
# st1821
# prohibiting
# levy
# on
# crop
# until
# has
# been
# gathered
# no
# lien
# attaches
# favor
# fi
# fa
# on
# growing
# crop
# nor
# does
# such
# lien
# attach
# until
# after
# crop
# has
# been
# gathered
# 5
# cases
# cite
# this
# headnote
# 1
# this
# trial
# right
# property
# under
# statute
# november
# 1840
# an
# execution
# issued
# from
# circuit
# court
# sumter
# at
# suit
# plaintiff
# error
# requiring
# sheriff
# county
# make
# goods
# c
# allen
# harrison
# ...

# %%
from textblob import TextBlob

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.stem import PorterStemmer
file5=''
f=PorterStemmer()
for a in file4.split('\n'):
  for b in a.split():
    file5 = file5 + '' + f.stem(b)
  file5 = file5 + '\n'
print(file5)
# Out:
# 5
# ala
# 740
# suprem
# court
# alabama
# adam
# v
# tanner
# horton
# june
# term
# 1843
# synopsi
# writ
# error
# circuit
# court
# sumter
# west
# headnot
# 2
# 1
# chattel
# mortgag
# crop
# grow
# crop
# ha
# such
# an
# exist
# as
# be
# subjectmatt
# mortgag
# or
# other
# contract
# which
# pass
# an
# interest
# vest
# possess
# either
# immedi
# or
# at
# futur
# time
# 4
# case
# cite
# thi
# headnot
# 2
# creditor
# remedi
# lien
# prioriti
# under
# st1821
# prohibit
# levi
# on
# crop
# until
# ha
# been
# gather
# no
# lien
# attach
# favor
# fi
# fa
# on
# grow
# crop
# nor
# doe
# such
# lien
# attach
# until
# after
# crop
# ha
# been
# gather
# 5
# case
# cite
# thi
# headnot
# 1
# thi
# trial
# right
# properti
# under
# statut
# novemb
# 1840
# an
# execut
# issu
# from
# circuit
# court
# sumter
# at
# suit
# plaintiff
# error
# requir
# sheriff
# counti
# make
# good
# c
# allen
# harrison
# other
# sum
# thirtyseven
# hundr
# seventyseven
# 80100
# dollar
# ...

# %%
from textblob import Word
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
file6 = ''
for a in file5.split('\n'):
  for b in a.split():
    file6 = file6 + '' + Word(b).lemmatize()
  file6=file + '\n'
print(file6)
# Out:
# 5 ala. 740
# supreme court of alabama.
# adams
# v.
# tanner and horton.
# june term, 1843.
# synopsis
# writ of error to the circuit court of sumter.
#
#
#
# west headnotes (2)
#
#
# [1]
# chattel mortgages
# crops
# a growing crop has such an existence as to be the subject-matter of a mortgage or other contract which passes an interest to vest in possession, either immediately or at a future time.
# 4 cases that cite this headnote
#
# [2]
# creditors’ remedies
# lien and priority
# under st.1821, prohibiting a levy on a crop until it has been gathered, no lien attaches in favor of a fi. fa. on a growing crop, nor does such lien attach until after the crop has been gathered.
# 5 cases that cite this headnote
#
# ...

# %%
f = open('file.csv','w')
f.write("output")
f.write(file6)
f.close()

# %%
import pandas as pd
rd = pd.read_csv("file.csv",sep='\t')
rd
# Out:
#                                                 output
# 0                                           5 ala. 740
# 1                            supreme court of alabama.
# 2                                                adams
# 3                                                   v.
# 4                                   tanner and horton.
# ..                                                 ...
# 143            there are no filings for this citation.
# 144                                 negative treatment
# 145  there are no negative treatment results for th...
# 146                                            history
# 147    there are no history results for this citation.
#
# [148 rows x 1 columns]

# %%
for a in range(10):
  print(TextBlob(rd['output'][a]).ngrams(1))
# Out:
# [WordList(['5']), WordList(['ala']), WordList(['740'])]
# [WordList(['supreme']), WordList(['court']), WordList(['of']), WordList(['alabama'])]
# [WordList(['adams'])]
# [WordList(['v'])]
# [WordList(['tanner']), WordList(['and']), WordList(['horton'])]
# [WordList(['june']), WordList(['term']), WordList(['1843'])]
# [WordList(['synopsis'])]
# [WordList(['writ']), WordList(['of']), WordList(['error']), WordList(['to']), WordList(['the']), WordList(['circuit']), WordList(['court']), WordList(['of']), WordList(['sumter'])]
# []
# [WordList(['west']), WordList(['headnotes']), WordList(['2'])]

# %%
for a in range(10):
  print(TextBlob(rd['output'][a]).ngrams(2))
# Out:
# [WordList(['5', 'ala']), WordList(['ala', '740'])]
# [WordList(['supreme', 'court']), WordList(['court', 'of']), WordList(['of', 'alabama'])]
# []
# []
# [WordList(['tanner', 'and']), WordList(['and', 'horton'])]
# [WordList(['june', 'term']), WordList(['term', '1843'])]
# []
# [WordList(['writ', 'of']), WordList(['of', 'error']), WordList(['error', 'to']), WordList(['to', 'the']), WordList(['the', 'circuit']), WordList(['circuit', 'court']), WordList(['court', 'of']), WordList(['of', 'sumter'])]
# []
# [WordList(['west', 'headnotes']), WordList(['headnotes', '2'])]

# %%
for a in range(10):
  print(TextBlob(rd['output'][a]).ngrams(3))
# Out:
# [WordList(['5', 'ala', '740'])]
# [WordList(['supreme', 'court', 'of']), WordList(['court', 'of', 'alabama'])]
# []
# []
# [WordList(['tanner', 'and', 'horton'])]
# [WordList(['june', 'term', '1843'])]
# []
# [WordList(['writ', 'of', 'error']), WordList(['of', 'error', 'to']), WordList(['error', 'to', 'the']), WordList(['to', 'the', 'circuit']), WordList(['the', 'circuit', 'court']), WordList(['circuit', 'court', 'of']), WordList(['court', 'of', 'sumter'])]
# []
# [WordList(['west', 'headnotes', '2'])]

# %%
table = (rd['output']).apply(lambda a: pd.value_counts(a.split(" "))).sum(axis = 0).reset_index()
table.columns = ['words','table']
print(table)
# Out:
#           words  table
# 0           740    1.0
# 1             5    6.0
# 2          ala.   14.0
# 3            of  142.0
# 4      alabama.    1.0
# ...         ...    ...
# 1155        let    1.0
# 1156    filings    2.0
# 1157  citation.    3.0
# 1158   negative    2.0
# 1159    history    2.0
#
# [1160 rows x 2 columns]

# %% [markdown]
# ## 2.2 Write a Python Program to extract all the years from the following sentence. (4 points)
#
# sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded cave to the divisive election of President Donald Trump."

# %%
# Write your code here
import re
years = re.findall('(\d{4})', 'The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies have happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys soccer team from a flooded cave to the divisive election of President Donald Trump.')
years[:] = [a for a in years if "1000" not in a]
years
# Out:
# ['2010', '2010', '2019']
